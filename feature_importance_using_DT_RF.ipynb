# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=5,n_classes=2,n_features=2,n_informative=2,n_redundant=0,random_state=43)

# %%
X
# Out:
# array([[ 1.229745  ,  1.07985428],
#        [-1.20634742, -0.36610726],
#        [ 0.88684452,  1.29698043],
#        [-0.81336698,  0.40088412],
#        [-1.79261093, -0.72123561]])

# %%
dt = DecisionTreeClassifier()
dt.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(dt)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[1] <= 0.017\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[1] <= 1.188\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
dt.feature_importances_
# Out:
# array([0., 1.])

# %%
rf = RandomForestClassifier(n_estimators=2)

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier(n_estimators=2)

# %%
rf.

# %%
rf.feature_importances_
# Out:
# array([0.41666667, 0.58333333])

# %%
print(rf.estimators_[0].feature_importances_)
print(rf.estimators_[1].feature_importances_)
# Out:
# [0. 1.]
# [0.83333333 0.16666667]
