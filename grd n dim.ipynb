# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes

# %%
X,y = load_diabetes(return_X_y = True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = .2 ,random_state = 23)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4588389962630465

# %%
lr.coef_
# Out:
# array([  -19.84569955,  -271.44799521,   518.60568284,   326.13921989,
#        -1003.87022985,   624.04203978,   220.7339424 ,   263.93739547,
#          829.85679767,    77.75019971])

# %%
class NdimGRD:
    def __init__(self,lrate=.01,epochs=500):
        self.coef_ = None
        self.intercept_ = None
        self.epochs = epochs
        self.lrate = .1
    def fit(self,X_train,y_train):
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])

        for i in range(self.epochs):
            y_hat = np.dot(X_train,self.coef_) + self.intercept_
            inter_slope = -2 * np.mean(y_train - y_hat)
            self.intercept_ = self.intercept_  - (self.lrate * inter_slope)

            coef_slope = -2*np.dot((y_train-y_hat).T,X_train)/X_train.shape[0]
            self.coef_ = self.coef_ - (self.lrate * coef_slope)

    def predict(self,X_test):
        return np.dot(X_test,self.coef_)+self.intercept_

# %%
r = NdimGRD()

# %%
r.fit(X_train,y_train)

# %%
r.intercept_
# Out:
# 149.64725404202198

# %%
r.coef_
# Out:
# array([  37.14747722,  -11.25630323,  154.88254436,  109.92560945,
#          43.07525071,   32.92977869, -101.39321379,  104.90017741,
#         149.3769435 ,   95.65561937])

# %%
y_p = r.predict(X_test)

# %%
r2_score(y_test,y_p)
# Out:
# 0.4462207842935503
